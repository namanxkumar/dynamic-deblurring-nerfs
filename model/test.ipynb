# %%
from dataset import Adobe240SingularPixels, Adobe240Singular

# %%
dataset = Adobe240Singular(
    blur_directory='data/adobe240singulardataset5/train_blur/GOPR9647/',
    sharp_directory='data/adobe240singulardataset5/train/GOPR9647/',
    image_extension='png',
    num_frames_per_blur=5,
)

# %%
print(len(dataset))
print(dataset.image_height)
print(dataset.image_width)
# Out:
# 108
# 88
# 160

# %%
index = 1
sample = dataset[index]
# print(sample['pixel_indices'].shape)
print(sample['blur_image'].shape)
print(sample['sharp_images'].shape)
print(sample['time_step'])
# Out:
# torch.Size([3, 22, 40])
# torch.Size([5, 3, 22, 40])
# 7

# %%
dataset.visualize(index)
# Out:
# blur_image_path:
#  data/adobe240singulardataset5/train_blur/GOPR9647/00016.png
# sharp_image_paths:
#  ['data/adobe240singulardataset5/train/GOPR9647/00014.png', 'data/adobe240singulardataset5/train/GOPR9647/00015.png', 'data/adobe240singulardataset5/train/GOPR9647/00016.png', 'data/adobe240singulardataset5/train/GOPR9647/00017.png', 'data/adobe240singulardataset5/train/GOPR9647/00018.png']

# %%
# import torch

# time_step = torch.tensor([3, 10])
# num_time_steps_per_frame = 7
# time_step_batch = torch.ones(
#     time_step.shape[0], num_time_steps_per_frame
# )
# time_step_batch = (
#     torch.arange(-(num_time_steps_per_frame//2), (num_time_steps_per_frame//2) + 1) * time_step_batch
# )  # Shape: (batch_size, num_time_steps_per_frame)
# time_step_batch = (
#     time_step_batch + time_step[:, None]
# )  # Shape: (batch_size, num_time_steps_per_frame)
# print(time_step_batch)
